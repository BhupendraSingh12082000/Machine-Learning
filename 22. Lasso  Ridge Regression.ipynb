# %% [markdown]
# # **Machine Learning -:  Lasso & Ridge Regression**
# -----
# -------

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as  pd
import numpy as np

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the Dataset

# %%
df = pd.read_csv('E:\Data Science Notes\8.MACHINE LEARNING\Melbourne_housing_FULL\Melbourne_housing_FULL.csv') 

df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# ### Find : Rows and columns

# %%
df.shape
# Out:
# (34857, 21)

# %% [markdown]
# ### Find number of Unique values Column wise

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %% [markdown]
# ### Accessing only  **required columns**

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 'Distance',
               'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price'] 
 
df = df[cols_to_use]

# %%
df.head()
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0
# ...

# %%
df.shape
# Out:
# (34857, 15)

# %% [markdown]
# ### Checking **NaN** values

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %% [markdown]
# ### Few of the columns filling with zero

# %%
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car'] 

df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %% [markdown]
# ### Filling **Landsize & BuildingArea**  columns with mean value

# %%
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean()) 
 
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %% [markdown]
# ### Droping NaN Value

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
df.shape
# Out:
# (27244, 15)

# %% [markdown]
# ### Create dummy variabe for categorical data

# %%
df = pd.get_dummies(df, drop_first = True) 

df.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0              False  ...
# 2       79.0000  1035000.0              False  ...
# 4      150.0000  1465000.0              False  ...
# 5      160.2564   850000.0              False  ...
# 6      142.0000  1600000.0              False  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                False                              False
# 2                                False                              False
# ...

# %% [markdown]
# ### Data Preparation

# %%
X = df.drop('Price', axis = 1) 

y = df['Price']

# %% [markdown]
# ### Splitting training and testing datasets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=2)

# %% [markdown]
# ### Model Creation

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %% [markdown]
# ### Train the Model

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Cheking the **Train** & **Test** Score

# %%
reg.score(X_train, y_train)
# Out:
# 0.6827792395792723

# %%
reg.score(X_test, y_test)*100
# Out:
# 13.853683161397202

# %% [markdown]
# ## Creating **Lasso**  Model Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha = 10, max_iter = 10, tol = 0.1)

# %% [markdown]
# ### Model Training with Lasso

# %%
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=10, max_iter=10, tol=0.1)

# %% [markdown]
# ### Checking the Score

# %%
lasso_reg.score(X_train, y_train)
# Out:
# 0.6809700583185653

# %%
lasso_reg.score(X_test, y_test)
# Out:
# 0.5831526769673665

# %% [markdown]
# ### Prediction

# %%
lasso_reg.predict(X_test)
# Out:
# array([1690618.69403271, 1090156.14518258,  893787.47842919, ...,
#         912282.56913699,  787426.92558376, 1183580.22083694])

# %% [markdown]
# ### Creating **Ridge** regression model

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha = 50, max_iter = 100, tol = 0.1)

# %%
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %% [markdown]
# ### Checking the Score

# %%
ridge_reg.score(X_train, y_train)
# Out:
# 0.6622376739684328

# %%
ridge_reg.score(X_test, y_test)
# Out:
# 0.6670848945194958

# %% [markdown]
# ### Prediction

# %%
y_test
# Out:
# 32841    1720000.0
# 10813     555000.0
# 7211      841000.0
# 17799     415000.0
# 3397      800000.0
#            ...
# 20856     762000.0
# 33317    1465000.0
# 25323     850000.0
# 4641      585000.0
# 11400     705000.0
# Name: Price, Length: 8174, dtype: float64

# %%
ridge_reg.predict(X_test)
# Out:
# array([1627362.97274832, 1040671.45389949,  905510.14874907, ...,
#         931940.4305978 ,  800466.36204516, 1241927.30653571])
